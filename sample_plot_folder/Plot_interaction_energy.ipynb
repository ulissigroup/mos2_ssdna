# %%
import csv

input1 = ["CA10.txt", "GT10.txt", "T10.txt", "T20.txt"]

test_datas = []

# f = open("CA10.txt")
# print(f.read())
# f.close


count = 0
for input in input1:
    test_data = []
    with open(input, 'rb') as fi:
        reader = csv.reader(fi, delimiter = "\n")
        for row in reader:
#             print test_data
            test_data.append(row[0].split(" "))
        test_datas.append(test_data)
        fi.close()

# print len(test_datas)
# print len(test_datas[0])
# print len(test_datas[1])
# print len(test_datas[2])
# print len(test_datas[3])



# print test_datas
# print test_datas[1]
# print test_datas[1][0]
# print test_datas[1][19]
# print test_datas[1][29]
# print test_datas[1][40]
# print test_datas[1][47]
# print len(test_datas)

frame = 0
elec = 26
vdw = 38
nonbond = 45
total = 52

print test_datas[1][1]
print test_datas[1][2]

# print test_datas[1][1][0]
# print float(test_datas[1][1][26])
# print float(test_datas[1][1][38])
# print float(test_datas[1][1][45])
# print float(test_datas[1][1][52])
# Out:
# ['0', '', '', '', '', '', '', '', '', '', '', '', '', '0', '', '', '', '', '', '', '', '', '', '', '', '', '+0', '', '', '', '', '', '', '', '', '', '', '', '-332.362', '', '', '', '', '', '-332.362', '', '', '', '', '', '-332.362', '', '', '', '', '', '']
# ['1', '', '', '', '', '', '', '', '', '', '', '', '', '1', '', '', '', '', '', '', '', '', '', '', '', '', '+0', '', '', '', '', '', '', '', '', '', '', '', '-323.001', '', '', '', '', '', '-323.001', '', '', '', '', '', '-323.001', '', '', '', '', '', '']

# %%
import numpy as np
import matplotlib.pyplot as plt

# print test_data
# print train_data



framerow = []
elecrow = []
vdwrow = []
nonbondrow = []
totalrow = []
for i in range(1, len(test_datas[1])):    
    numcount = 0
    for j in range(0, len(test_datas[1][i])):
        if(test_datas[1][i][j] != ""):
            numcount += 1
            if(numcount == 1):
                framerow.append(float(test_datas[1][i][j]))
            elif(numcount == 3):
                elecrow.append(float(test_datas[1][i][j]))
            elif(numcount == 4):
                vdwrow.append(float(test_datas[1][i][j]))
            elif(numcount == 5):
                nonbondrow.append(float(test_datas[1][i][j]))
                continue
            elif(numcount == 6):
                totalrow.append(float(test_datas[1][i][j]))
            else: continue


# plt.title("GT10")
plt.xlabel("Num Frames")
plt.ylabel("Interaction Energy Total")
plt.plot(framerow, totalrow, label = "GT10")
plt.legend()
# plt.show()



framerow = []
elecrow = []
vdwrow = []
nonbondrow = []
totalrow = []
for i in range(1, len(test_datas[0])):    
    numcount = 0
    for j in range(0, len(test_datas[0][i])):
        if(test_datas[0][i][j] != ""):
            numcount += 1
            if(numcount == 1):
                framerow.append(float(test_datas[0][i][j]))
            elif(numcount == 3):
                elecrow.append(float(test_datas[0][i][j]))
            elif(numcount == 4):
                vdwrow.append(float(test_datas[0][i][j]))
            elif(numcount == 5):
                nonbondrow.append(float(test_datas[0][i][j]))
            elif(numcount == 6):
                totalrow.append(float(test_datas[0][i][j]))
            else: continue


# plt.title("CA10")
plt.xlabel("Num Frames")
plt.ylabel("Interaction Energy Total")
plt.plot(framerow, totalrow, label = "CA10")
plt.legend()
# plt.show()



framerow = []
elecrow = []
vdwrow = []
nonbondrow = []
totalrow = []
for i in range(1, len(test_datas[2])):    
    numcount = 0
    for j in range(0, len(test_datas[2][i])):
        if(test_datas[2][i][j] != ""):
            numcount += 1
            if(numcount == 1):
                framerow.append(float(test_datas[2][i][j]))
            elif(numcount == 3):
                elecrow.append(float(test_datas[2][i][j]))
            elif(numcount == 4):
                vdwrow.append(float(test_datas[2][i][j]))
            elif(numcount == 5):
                nonbondrow.append(float(test_datas[2][i][j]))
            elif(numcount == 6):
                totalrow.append(float(test_datas[2][i][j]))
            else: continue


# plt.title("T10")
plt.xlabel("Num Frames")
plt.ylabel("Interaction Energy Total")
plt.plot(framerow, totalrow, label = "T10")
plt.legend()
# plt.show()

framerow = []
elecrow = []
vdwrow = []
nonbondrow = []
totalrow = []
for i in range(1, len(test_datas[3])):    
    numcount = 0
    for j in range(0, len(test_datas[3][i])):
        if(test_datas[3][i][j] != ""):
            numcount += 1
            if(numcount == 1):
                framerow.append(float(test_datas[3][i][j]))
            elif(numcount == 3):
                elecrow.append(float(test_datas[3][i][j]))
            elif(numcount == 4):
                vdwrow.append(float(test_datas[3][i][j]))
            elif(numcount == 5):
                nonbondrow.append(float(test_datas[3][i][j]))
            elif(numcount == 6):
                totalrow.append(float(test_datas[3][i][j]))
            else: continue


# plt.title("Interaction ENER")
plt.xlabel("Num Frames")
plt.ylabel("Interaction Energy [kcal/mol]")
plt.plot(framerow, totalrow,label = "T20")
plt.legend()
plt.show()
